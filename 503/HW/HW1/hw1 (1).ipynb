# %% [markdown]
# ## Question 1
#
# **Consider the population of students taking STATS 503 this semester at the University of Michigan.**
#
# **(a) [3 points] Name three variables related to academics that you could collect or measure about each student in this population. Of these three variables, one must be ordinal, one must be categorical, and one must be continuous.**

# %% [markdown]
# Three academic-related variables that could be collected for each student taking STATS 503 at the University of Michigan are
# - (Ordinal) Year in graduate program (e.g. 1st, 2nd, etc.)
# - (Categorical) Primary academic program or department (e.g. Statistics, Biostatistics, Economics, etc.)
# - (Continuous) Undergraduate or graduate cumulative GPA

# %% [markdown]
# **(b) [3 points] Suppose you have collected a dataset containing these variables for the population of students taking STATS 503 this semester. Now consider using this dataset to make inferences about a different population. Name another population about which we could plausibly make inferences. Name another population that would be more difficult to make inferences about.**

# %% [markdown]
# Using the dataset collected from students taking STATS 503 at the University of Michigan this semester:
#
# * **Plausible population for inference:**
#   Graduate students taking other applied statistics or data science courses at the University of Michigan (e.g., students enrolled in similar upper-level statistics or quantitative methods courses). These students are likely to have comparable academic backgrounds, preparation, and grading structures, making inference more reasonable.
#
# * **More difficult population for inference:**
#   Undergraduate students at the University of Michigan, or students taking introductory statistics courses at other universities. These populations may differ substantially in academic preparation, course rigor, grading norms, and institutional context, limiting the validity of inference from the STATS 503 student data.

# %% [markdown]
# ## Question 2
# **Explain whether each scenario is a classification or regression problem, and indicate whether we are most interested in inference or prediction. Finally, provide the number of samples (n) and the number of features (p).**
#
# **(a) [3 points] We collect a set of data on the top 500 firms in the United States. For each firm, we record the profit, the number of employees, the industry, and the CEO salary. We are interested in understanding which factors affect CEO salary.**

# %% [markdown]
# ### (a)
#
# * **Type of problem:** Regression
# * **Goal:** Inference (we want to understand which factors affect CEO salary)
# * **Number of samples (n):** 500 (the top 500 firms in the United States)
# * **Number of features (p):** 3
#
#   * Profit
#   * Number of employees
#   * Industry
#
# (CEO salary is the response variable.)

# %% [markdown]
# **(b) [3 points] We are considering releasing a new product and want to know whether it will be a success or a failure. We collect data on 20 similar products that were previously launched. For each product, we have recorded whether it was a success or failure, the price charged for the product, the marketing budget, the competition price, and ten other variables.**

# %% [markdown]
# ### (b)
#
# * **Type of problem:** Classification (success vs. failure)
# * **Goal:** Prediction (we want to predict whether a new product will succeed or fail)
# * **Number of samples (n):** 20 (previously launched products)
# * **Number of features (p):** 13
#
#   * Price
#   * Marketing budget
#   * Competition price
#   * 10 additional variables
#
# (The response variable is whether the product was a success or failure.)

# %% [markdown]
# **(c) [3 points] We are interested in predicting the percentage change in the USD/Euro exchange rate in relation to the weekly changes in the world stock markets. Hence, we collect weekly data for all of 2012. For each week, we record the percent change in the USD/Euro, the percent change in the US market, the percent change in the British market, and the percent change in the German market.**

# %% [markdown]
# ### (c)
#
# * **Type of problem:** Regression
# * **Goal:** Prediction (predicting percentage change in the exchange rate)
# * **Number of samples (n):** 52 (weekly data for one year)
# * **Number of features (p):** 3
#
#   * Percent change in the U.S. stock market
#   * Percent change in the U.K. stock market
#   * Percent change in the German stock market
#
# (The response variable is the percent change in the USD/Euro exchange rate.)

# %% [markdown]
# ## Question 3
#
# **[3 points] You have a dataset. You are considering a collection of different methods that you could apply to this dataset in order to estimate the regression function. The methods range from very inflexible (only capable of representing a small class of true regression functions) to very flexible (capable of fitting a very large class of true regression functions).**
#
# **(a) True or false: typically, the bias of your estimate will be lower with more flexible methods.**
#
# More flexible methods can approximate a wider class of true regression functions, reducing systematic error due to model misspecification and therefore lowering bias.
#
# **A. True**
#
# **B. False**

# %%
# Fill in A or B
mcq_answer = "A" # True

# %% [markdown]
# **(b) True or false: typically, the variance of your estimate will be lower with more flexible methods.**
#
# **A. True**
#
# **B. False**
#
# More flexible methods tend to be more sensitive to random fluctuations in the training data, which increases variance rather than decreases it.

# %%
# Fill in A or B
mcq_answer = "B" # False

# %% [markdown]
# **(c) True or false: typically, irreducible error will be lower with more flexible methods.**
#
# **A. True**
#
# **B. False**
#
# Irredubile error, i.e. $Var(\epsilon|X)$, is determined by the inherent noise in the data-generating process and cannot be reduced by choosing a more flexible (or less flexible) model.

# %%
# Fill in A or B
mcq_answer = "B"

# %% [markdown]
# ## Question 4
#
# **[4 points] Consider gathering a dataset and using it to estimate the regression function. Assume the data-generating distribution is well-behaved (e.g., assume that the true regression function is continuous) and typical of what we would find in real-world settings. Answer true or false.**
#
# **(a) As the size of your training dataset tends to infinity (for a fixed number of neighbors, K), the bias of the KNN regression estimate will tend to 0.**
#
# **A. True**
#
# **B. False**
#
# As the sample size grows, the
# K nearest neighbors to a point become arbitrarily close. Since the true regression function is continuous, the average response in this shrinking neighborhood converges to the true regression function value, so the bias tends to zero.

# %%
# Fill in A or B
mcq_answer = "A"

# %% [markdown]
# **(b) As the size of your training dataset tends to infinity (for a fixed number of neighbors, K), the variance of the KNN regression estimate will tend to 0.**
#
# **A. True**
#
# **B. False**
#
# With fixed K, KNN always averages a fixed number of noisy points, so the randomness in those points never dissapears, even for a larger (infinite) sample size.

# %%
# Fill in A or B
mcq_answer = "B"

# %% [markdown]
# **(c) As the size of your training dataset tends to infinity, the bias of a least squares linear regression estimate will tend to zero.**
#
#
# **A. True**
#
# **B. False**
#
# If the true regression funciton is not exactly linear, least squares suffers from model misspecification, and the bias does not dissapear even with infinite data.

# %%
# Fill in A or B
mcq_answer = "B"

# %% [markdown]
# **(d) As the size of your training dataset tends to infinity, the variance of a least squares linear regression estimate will tend to 0.**
#
# **A. True**
#
# **B. False**
#
# As the training sample size increases, least squares coefficient estimates become more stable, causing the variance of the estimated regression function to converge to zero.

# %%
# Fill in A or B
mcq_answer = "A"

# %% [markdown]
# ## Question 5
# For points (a) through (d) print out your answer. That is how the autograder captures yout solution.
#
#
# **Load the `college_train` data set as a data frame.**
#
# **(a) [1 point] Access the `shape` property of your data frame to compute the number of samples we have and the number of variables measured about each sample.**

# %%
# !cp -n fixtures/* .
import pandas as pd

# %%
data = pd.read_csv("college_train.csv")
print(data.shape)
# Out:
# (650, 19)

# %% [markdown]
# **(b) [1 point] Compute the mean and standard deviation of the `Books` feature.**

# %%
# data.columns
print(data['Books'].mean())
# Out:
# 551.6553846153846

# %%
print(data['Books'].std())
# Out:
# 168.64335324879607

# %% [markdown]
# **(c) [2 points] For how many samples is the `Terminal` feature at least 90?**

# %%
print(data[data['Terminal'] >= 90].shape[0])
# Out:
# 207

# %% [markdown]
# **(d) [2 points] Create a new dataframe that only includes samples where `Private` is equal to `Yes`.**
#
# **i. What is the mean value of `Books` in the new dataframe?**
# **ii. What is the standard deviation of `Books` in the new dataframe?**

# %%
data.modified = data.copy()
data.modified = data.modified[data.modified['Private'] == 'Yes']
# data.modified.head()

print(data.modified['Books'].mean())
# Out:
# 550.2972399150743

# %%
print(data.modified['Books'].std())
# Out:
# 179.7250049878915

# %% [markdown]
# **(e) [1 point] Use a for loop to print the following text:**
#
# ```
# Hello world 1.
# Hello world 2.
# Hello world 4.
# Hello world 8.
# Hello world 16.
# ```

# %%
for i in [1,2,4,8,16]: 
    print(f"Hello world {i}.")
# Out:
# Hello world 1.
# Hello world 2.
# Hello world 4.
# Hello world 8.
# Hello world 16.

# %% [markdown]
# **(f) [1 point] Create a markdown Jupyter cell with the contents in `sample.png`.**

# %% [markdown]
# ![sample](sample.png)
